# %%
# Initial imports
import pandas as pd
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %% [markdown]
# ## Loading and Preprocessing Loans Encoded Data
#
# Load the `sba_loans_encoded.csv` in a pandas DataFrame called `df_loans`

# %%
# Read the CSV file into a Pandas DataFrame
df = pd.read_csv('insurance_claims.csv')

# Review the DataFrame
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
# List of columns to drop
columns_to_drop = ['policy_bind_date', 'policy_state', 'policy_csl', 'policy_deductable',\
                   'umbrella_limit', 'insured_zip','insured_occupation', 'insured_hobbies','incident_date',\
                   'auto_make','auto_model', 'auto_year',  '_c39','incident_state', 'incident_city' ,'policy_number' ,'incident_location'  ]

# Drop the specified columns
clean_df = df.drop(columns=columns_to_drop)

# Check the result
clean_df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_annual_premium', 'insured_sex',
#        'insured_education_level', 'insured_relationship', 'capital-gains',
#        'capital-loss', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'fraud_reported'],
#       dtype='object')

# %%
clean_df['collision_type'].unique()
# Out:
# array(['Side Collision', '?', 'Rear Collision', 'Front Collision'],
#       dtype=object)

# %%
clean_df['collision_type'] = clean_df['collision_type'].replace('?', 'NO')
clean_df.dropna(subset=['authorities_contacted'], inplace=True)

# %%
# Check the number of data per column
clean_df.count()
# Out:
# months_as_customer             909
# age                            909
# policy_annual_premium          909
# insured_sex                    909
# insured_education_level        909
# insured_relationship           909
# capital-gains                  909
# capital-loss                   909
# incident_type                  909
# collision_type                 909
# incident_severity              909
# authorities_contacted          909
# incident_hour_of_the_day       909
# number_of_vehicles_involved    909
# property_damage                909
# bodily_injuries                909
# witnesses                      909
# police_report_available        909
# total_claim_amount             909
# injury_claim                   909
# property_claim                 909
# vehicle_claim                  909
# fraud_reported                 909
# dtype: int64

# %%
# Replace 'FEMALE' with 0 and 'MALE' with 1 in the 'insured_sex' column
clean_df['insured_sex'] = clean_df['insured_sex'].map({'FEMALE': 0, 'MALE': 1})
# Replace '?' with 'N' in the 'police_report_available' column
clean_df['police_report_available'] = clean_df['police_report_available'].replace('?', 'NO')
clean_df['property_damage'] = clean_df['property_damage'].replace('?', 'NO')

# %%
clean_df.head(20)
# Out:
#     months_as_customer  age  policy_annual_premium  insured_sex  \
# 0                  328   48                1406.91            1
# 1                  228   42                1197.22            1
# 2                  134   29                1413.14            0
# 3                  256   41                1415.74            0
# 5                  256   39                1351.10            0
# 6                  137   34                1333.35            1
# 7                  165   37                1137.03            1
# 8                   27   33                1442.99            0
# 9                  212   42                1315.68            1
# 10                 235   42                1253.12            0
# 11                 447   61                1137.16            0
# 12                  60   23                1215.36            1
# 14                 180   38                1301.13            0
# 15                 473   58                1131.40            0
# 16                  70   26                1199.44            1
# 17                 140   31                 708.64            1
# 18                 160   37                1374.22            0
# 19                 196   39                1475.73            0
# 20                 460   62                1187.96            1
# 21                 217   41                 875.15            0
#
#    insured_education_level insured_relationship  capital-gains  capital-loss  \
# 0                       MD              husband          53300             0
# 1                       MD       other-relative              0             0
# 2                      PhD            own-child          35100             0
# 3                      PhD            unmarried          48900        -62400
# 5                      PhD            unmarried              0             0
# 6                      PhD              husband              0        -77000
# 7                Associate            unmarried              0             0
# 8                      PhD            own-child              0             0
# 9                      PhD                 wife              0        -39300
# 10                 Masters       other-relative          38400             0
# 11             High School       other-relative              0        -51000
# 12                      MD                 wife              0             0
# 14                 College        not-in-family          41300        -55500
# 15                      MD       other-relative          55700             0
# 16                 College            own-child          63600             0
# 17             High School            unmarried          53500             0
# 18                      MD       other-relative          45500        -37800
# 19             High School            own-child          57000        -27300
# 20                      JD            own-child              0             0
# 21               Associate            own-child          46700             0
#
#                incident_type   collision_type  ...  \
# 0   Single Vehicle Collision   Side Collision  ...
# 1              Vehicle Theft               NO  ...
# 2    Multi-vehicle Collision   Rear Collision  ...
# 3   Single Vehicle Collision  Front Collision  ...
# 5    Multi-vehicle Collision   Rear Collision  ...
# 6    Multi-vehicle Collision  Front Collision  ...
# 7    Multi-vehicle Collision  Front Collision  ...
# 8   Single Vehicle Collision  Front Collision  ...
# 9   Single Vehicle Collision   Rear Collision  ...
# 10  Single Vehicle Collision  Front Collision  ...
# 11   Multi-vehicle Collision  Front Collision  ...
# 12  Single Vehicle Collision   Rear Collision  ...
# 14  Single Vehicle Collision   Rear Collision  ...
# 15   Multi-vehicle Collision   Side Collision  ...
# 16   Multi-vehicle Collision   Rear Collision  ...
# 17  Single Vehicle Collision   Side Collision  ...
# 18  Single Vehicle Collision   Side Collision  ...
# 19   Multi-vehicle Collision   Side Collision  ...
# 20   Multi-vehicle Collision   Rear Collision  ...
# 21   Multi-vehicle Collision   Side Collision  ...
#
#    number_of_vehicles_involved property_damage  bodily_injuries  witnesses  \
# 0                            1             YES                1          2
# 1                            1              NO                0          0
# 2                            3              NO                2          3
# 3                            1              NO                1          2
# 5                            3              NO                0          2
# 6                            3              NO                0          0
# 7                            3              NO                2          2
# 8                            1              NO                1          1
# 9                            1              NO                2          1
# 10                           1             YES                2          2
# 11                           3             YES                1          2
# 12                           1             YES                1          0
# 14                           1              NO                0          2
# 15                           4             YES                0          0
# 16                           3              NO                1          2
# 17                           1              NO                0          2
# 18                           1             YES                1          0
# 19                           3              NO                2          0
# 20                           3              NO                1          0
# 21                           3              NO                1          2
#
#    police_report_available  total_claim_amount  injury_claim property_claim  \
# 0                      YES               71610          6510          13020
# 1                       NO                5070           780            780
# 2                       NO               34650          7700           3850
# 3                       NO               63400          6340           6340
# 5                       NO               64100          6410           6410
# 6                       NO               78650         21450           7150
# 7                      YES               51590          9380           9380
# 8                      YES               27700          2770           2770
# 9                       NO               42300          4700           4700
# 10                      NO               87010          7910          15820
# 11                     YES              114920         17680          17680
# 12                      NO               56520          4710           9420
# 14                     YES               46200          4200           8400
# 15                      NO               63120         10520          10520
# 16                     YES               52110          5790           5790
# 17                     YES               77880         14160           7080
# 18                      NO               72930          6630          13260
# 19                      NO               60400          6040           6040
# 20                      NO               47160             0           5240
# 21                      NO               37840             0           4730
#
#     vehicle_claim  fraud_reported
# 0           52080               Y
# 1            3510               Y
# 2           23100               N
# 3           50720               Y
# 5           51280               Y
# 6           50050               N
# 7           32830               N
# 8           22160               N
# 9           32900               N
# 10          63280               N
# 11          79560               N
# 12          42390               N
# 14          33600               Y
# 15          42080               Y
# 16          40530               N
# 17          56640               N
# 18          53040               N
# 19          48320               N
# 20          41920               N
# 21          33110               N
#
# [20 rows x 23 columns]

# %% [markdown]
# ### 2. Separate the features `X` from the target `y`

# %%
# Separate the features, X, from the target variable, y
y = clean_df['fraud_reported']
X = clean_df.drop(columns='fraud_reported', axis=1)
# Preview the features data
X.head()
# Out:
#    months_as_customer  age  policy_annual_premium  insured_sex  \
# 0                 328   48                1406.91            1
# 1                 228   42                1197.22            1
# 2                 134   29                1413.14            0
# 3                 256   41                1415.74            0
# 5                 256   39                1351.10            0
#
#   insured_education_level insured_relationship  capital-gains  capital-loss  \
# 0                      MD              husband          53300             0
# 1                      MD       other-relative              0             0
# 2                     PhD            own-child          35100             0
# 3                     PhD            unmarried          48900        -62400
# 5                     PhD            unmarried              0             0
#
#               incident_type   collision_type  ... incident_hour_of_the_day  \
# 0  Single Vehicle Collision   Side Collision  ...                        5
# 1             Vehicle Theft               NO  ...                        8
# 2   Multi-vehicle Collision   Rear Collision  ...                        7
# 3  Single Vehicle Collision  Front Collision  ...                        5
# 5   Multi-vehicle Collision   Rear Collision  ...                       19
#
#   number_of_vehicles_involved  property_damage  bodily_injuries witnesses  \
# 0                           1              YES                1         2
# 1                           1               NO                0         0
# 2                           3               NO                2         3
# 3                           1               NO                1         2
# 5                           3               NO                0         2
#
#    police_report_available  total_claim_amount injury_claim  property_claim  \
# 0                      YES               71610         6510           13020
# 1                       NO                5070          780             780
# 2                       NO               34650         7700            3850
# 3                       NO               63400         6340            6340
# 5                       NO               64100         6410            6410
#
#    vehicle_claim
# 0          52080
# 1           3510
# 2          23100
# 3          50720
# 5          51280
#
# [5 rows x 22 columns]

# %% [markdown]
# # **2. Create the target vector by assigning the values of the `Default` column from the DataFrame.**

# %%
# Define target vector
y = clean_df['fraud_reported'].values.reshape(-1, 1)
y[:5]
# Out:
# array([['Y'],
#        ['Y'],
#        ['N'],
#        ['Y'],
#        ['Y']], dtype=object)

# %% [markdown]
# Split the data into training and testing sets.

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %% [markdown]
# ## **3. Encode the categorical variables from the features data using `get_dummies`.**

# %%
# Encode the categorical variables using get_dummies
X = pd.get_dummies(X)

# %%
# Review the features data
X.head()
# Out:
#    months_as_customer  age  policy_annual_premium  insured_sex  capital-gains  \
# 0                 328   48                1406.91            1          53300
# 1                 228   42                1197.22            1              0
# 2                 134   29                1413.14            0          35100
# 3                 256   41                1415.74            0          48900
# 5                 256   39                1351.10            0              0
#
#    capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0             0                         5                            1
# 1             0                         8                            1
# 2             0                         7                            3
# 3        -62400                         5                            1
# 5             0                        19                            3
#
#    bodily_injuries  witnesses  ...  incident_severity_Total Loss  \
# 0                1          2  ...                         False
# 1                0          0  ...                         False
# 2                2          3  ...                         False
# 3                1          2  ...                         False
# 5                0          2  ...                         False
#
#    incident_severity_Trivial Damage  authorities_contacted_Ambulance  \
# 0                             False                            False
# 1                             False                            False
# 2                             False                            False
# 3                             False                            False
# 5                             False                            False
#
#    authorities_contacted_Fire  authorities_contacted_Other  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                        False
# 3                       False                        False
# 5                        True                        False
#
#    authorities_contacted_Police  property_damage_NO  property_damage_YES  \
# 0                          True               False                 True
# 1                          True                True                False
# 2                          True                True                False
# 3                          True                True                False
# 5                         False                True                False
#
#    police_report_available_NO  police_report_available_YES
# 0                       False                         True
# 1                        True                        False
# 2                        True                        False
# 3                        True                        False
# 5                        True                        False
#
# [5 rows x 47 columns]

# %% [markdown]
# Use the `StandardScaler` to scale the features data, remember that only `X_train` and `X_testing` DataFrames should be scaled.

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
X_scaler = scaler.fit(X_train)

# %%
# Scale the training data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # **Fitting the Support vector machine linear classifier**

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC
model = SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='linear')

# %%
# Train the model using the training data
SVC(kernel='linear')
# Out:
# SVC(kernel='linear')

# %% [markdown]
# # **Make predictions using the testing data.**

# %%
# Model Accuracy
print('Test Acc: %.3f' % model.score(X_test, y_test))
# Out:
# Test Acc: 0.798

# %% [markdown]
# **Generate the classification report for the test data.**

# %%
# Calculate the classification report
from sklearn.metrics import classification_report

# Define class names
target_names = ["N", "Y"]

# Print classification report
print(classification_report(y_test, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#            N       0.80      0.99      0.89       181
#            Y       0.67      0.04      0.08        47
#
#     accuracy                           0.80       228
#    macro avg       0.73      0.52      0.48       228
# weighted avg       0.77      0.80      0.72       228

# %% [markdown]
# ## Analysis Questions
#
# Finally, analyze the model's evaluation results and answer the following questions.
#
# * **Question 1:** Would you trust this model to detect if a fraud will be detected?
#
#  * **Answer:**  Based on the classification report, the Support Vector Machine (SVM) model achieves an accuracy of 80%, which seems relatively high. However, when we look at the F1-score and recall for class 'Y' (fraud reported), they are only 0.08 and 0.04, respectively. This indicates that the model's ability to correctly identify fraud reports is very low. Therefore, I would not trust this model to reliably detect if a fraud will be detected.
